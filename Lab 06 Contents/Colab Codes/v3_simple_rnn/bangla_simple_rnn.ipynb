# %%
# -*- coding: utf-8 -*-
"""somoresh_NLP.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/18NO283FRrrQz52zAKCikrj271Vzwc-6L
"""

import numpy as np
import pandas as pd
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout, Bidirectional
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import pickle
import time

# Load and preprocess the dataset from Excel
def load_and_preprocess_data(file_path):
    try:
        # Read the Excel file
        file_path = '/content/somoresh.xlsx'
        df = pd.read_excel(file_path)
        print("Successfully read Excel file")
        print(f"Columns: {df.columns.tolist()}")

        # Check which column contains text data
        text_column = None
        for col in df.columns:
            # Check if column contains text (string) data
            if df[col].dtype == 'object' or df[col].apply(lambda x: isinstance(x, str)).any():
                sample_value = df[col].dropna().iloc[0] if not df[col].dropna().empty else ""
                if isinstance(sample_value, str) and any('\u0980' <= c <= '\u09FF' for c in sample_value):
                    text_column = col
                    print(f"Using column '{text_column}' for Bangla text")
                    break

        if text_column is None:
            # If no obvious text column, try to find one with text
            for col in df.columns:
                sample_value = str(df[col].dropna().iloc[0]) if not df[col].dropna().empty else ""
                if any('\u0980' <= c <= '\u09FF' for c in sample_value):
                    text_column = col
                    print(f"Using column '{text_column}' for Bangla text (detected)")
                    break

        if text_column is None:
            raise ValueError("Could not find a column with Bangla text in the Excel file")

        # Combine all text segments
        all_text = " ".join(df[text_column].astype(str).tolist())

        # Clean the text - keep only Bangla characters, numbers, and basic punctuation
        all_text = re.sub(r'[^\u0980-\u09FF0-9\s\.\,\?\!]', '', all_text)

        # Tokenize into words
        words = all_text.split()

        return words, df, text_column

    except Exception as e:
        print(f"Error reading Excel file: {str(e)}")
        print("Using fallback sample data...")

        # Fallback sample data
        sample_text = "এরকম ঘটনা এই শহরে এর আগে ঘটেনি। তার আগে শহরটার পরিচয় দেওয়া দরকার। আমাদের চেনাশোনা আর পাঁচটা শহরের সঙ্গে এই শহরটির পার্থক্য হল এখানে আইন-শৃঙ্খলা সবাই মানে, বয়স্কদের শ্রদ্ধা করে কনিষ্ঠরা, কারণ এই শহরটিকে ওঁরা নিজেদের রক্ত দিয়েই তৈরি করেছেন বলা যায়। শহরের জন্যে প্রত্যেকেরই মায়া আছে, তাই কোনও ত্রুটিবিচ্যুতি সচরাচর চোখে পড়ে না। অথচ মাত্র পঞ্চাশ বছর এই শহরটির আয়ু। হিমালয়ের ওপর এমন টাটকা বাতাসের রাজত্বে ছবির মতো এই শহরটা দেখলে চোখ জুড়িয়ে যায়। খুব কাছের সমতলের বড় জংশন স্টেশনে পৌঁছতে বড়জোর ঘণ্টা আড়াই মতো সময় লাগে।"
        words = sample_text.split()
        return words, pd.DataFrame([sample_text], columns=['text']), 'text'

# Create sequences for training
def create_sequences(words, seq_length=5):
    sequences = []
    for i in range(seq_length, len(words)):
        seq = words[i-seq_length:i+1]
        sequences.append(" ".join(seq))
    return sequences

# Prepare the data for training
def prepare_data(sequences, tokenizer=None):
    if tokenizer is None:
        tokenizer = Tokenizer()
        tokenizer.fit_on_texts(sequences)

    # Convert text to sequences
    sequences = tokenizer.texts_to_sequences(sequences)

    # Get vocabulary size
    vocab_size = len(tokenizer.word_index) + 1

    # Convert to numpy array
    sequences = np.array(sequences)

    # Split into input and output
    X = sequences[:, :-1]
    y = sequences[:, -1]

    # One-hot encode the output
    y = to_categorical(y, num_classes=vocab_size)

    return X, y, tokenizer, vocab_size

# Build the model with SimpleRNN
def build_model(vocab_size, seq_length, embedding_dim=100, rnn_units=150):
    print("\n" + "="*50)
    print("BUILDING MODEL ARCHITECTURE (SimpleRNN)")
    print("="*50)

    model = Sequential()

    print(f"Adding Embedding layer: input_dim={vocab_size}, output_dim={embedding_dim}, input_length={seq_length}")
    model.add(Embedding(vocab_size, embedding_dim, input_length=seq_length))

    print(f"Adding Bidirectional SimpleRNN layer: units={rnn_units}, return_sequences=True")
    model.add(Bidirectional(SimpleRNN(rnn_units, return_sequences=True)))

    print("Adding Dropout layer: rate=0.3")
    model.add(Dropout(0.3))

    print(f"Adding SimpleRNN layer: units={rnn_units}")
    model.add(SimpleRNN(rnn_units))

    print("Adding Dropout layer: rate=0.3")
    model.add(Dropout(0.3))

    print(f"Adding Dense layer: units={rnn_units}, activation='relu'")
    model.add(Dense(rnn_units, activation='relu'))

    print("Adding Dropout layer: rate=0.2")
    model.add(Dropout(0.2))

    print(f"Adding Output Dense layer: units={vocab_size}, activation='softmax'")
    model.add(Dense(vocab_size, activation='softmax'))

    print("\n" + "="*50)
    print("COMPILING MODEL")
    print("="*50)
    print("Using categorical_crossentropy loss function")
    print("Using adam optimizer")
    print("Tracking accuracy metric")

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# Alternative simpler model (uncomment to use)
def build_simple_model(vocab_size, seq_length, embedding_dim=100, rnn_units=128):
    print("\n" + "="*50)
    print("BUILDING SIMPLE MODEL ARCHITECTURE")
    print("="*50)

    model = Sequential()

    print(f"Adding Embedding layer: input_dim={vocab_size}, output_dim={embedding_dim}")
    model.add(Embedding(vocab_size, embedding_dim, input_length=seq_length))

    print(f"Adding SimpleRNN layer: units={rnn_units}")
    model.add(SimpleRNN(rnn_units))

    print("Adding Dropout layer: rate=0.2")
    model.add(Dropout(0.2))

    print(f"Adding Dense layer: units={rnn_units//2}, activation='relu'")
    model.add(Dense(rnn_units//2, activation='relu'))

    print(f"Adding Output Dense layer: units={vocab_size}, activation='softmax'")
    model.add(Dense(vocab_size, activation='softmax'))

    print("\nCompiling simple model...")
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# Train the model
def train_model(model, X, y, epochs=100, batch_size=64):
    print("\n" + "="*50)
    print("TRAINING MODEL")
    print("="*50)
    print(f"Training on {X.shape[0]} samples")
    print(f"Using batch size: {batch_size}")
    print(f"Maximum epochs: {epochs}")
    print("Using callbacks: EarlyStopping, ReduceLROnPlateau")

    early_stop = EarlyStopping(
        monitor='loss',
        patience=10,
        verbose=1,
        restore_best_weights=True
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='loss',
        patience=5,
        factor=0.5,
        verbose=1
    )

    print("\nStarting training...")
    start_time = time.time()

    history = model.fit(
        X, y,
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop, reduce_lr],
        verbose=1
    )

    end_time = time.time()
    training_time = end_time - start_time
    print(f"\nTraining completed in {training_time:.2f} seconds")

    return history

# Predict next word
def predict_next_word(model, tokenizer, text, seq_length, num_predictions=3):
    # Clean the input text
    text = re.sub(r'[^\u0980-\u09FF0-9\s\.\,\?\!]', '', text)

    # Tokenize
    words = text.split()

    # Take the last seq_length words
    if len(words) > seq_length:
        words = words[-seq_length:]
    elif len(words) < seq_length:
        # Pad with empty strings if needed
        words = [''] * (seq_length - len(words)) + words

    # Convert to sequence
    sequence = tokenizer.texts_to_sequences([" ".join(words)])

    # Pad if necessary
    sequence = pad_sequences(sequence, maxlen=seq_length)

    # Predict
    prediction = model.predict(sequence, verbose=0)

    # Get top predictions
    top_indices = np.argsort(prediction[0])[-num_predictions:][::-1]

    # Convert indices to words
    word_preds = []
    for idx in top_indices:
        for word, index in tokenizer.word_index.items():
            if index == idx:
                word_preds.append(word)
                break

    return word_preds

# Main execution
def main():
    # Parameters
    SEQ_LENGTH = 5
    EPOCHS = 100
    BATCH_SIZE = 64
    EMBEDDING_DIM = 128
    RNN_UNITS = 256

    # Load and preprocess data
    print("Loading and preprocessing data...")
    file_path = "/content/somoresh.xlsx"  # Your Excel file path
    words, df, text_column = load_and_preprocess_data(file_path)

    print(f"Loaded {len(words)} words from dataset")
    print(f"Sample words: {words[:10]}")

    # Create sequences
    sequences = create_sequences(words, SEQ_LENGTH)
    print(f"Created {len(sequences)} sequences")

    # Prepare data for training
    X, y, tokenizer, vocab_size = prepare_data(sequences)
    print(f"Vocabulary size: {vocab_size}")
    print(f"Input shape: {X.shape}, Output shape: {y.shape}")

    # Build model - Choose one of the following:

    # Option 1: Complex model with Bidirectional RNN
    print("\nBuilding complex RNN model...")
    model = build_model(vocab_size, SEQ_LENGTH, EMBEDDING_DIM, RNN_UNITS)

    # Option 2: Simple model (uncomment to use instead)
    # print("\nBuilding simple RNN model...")
    # model = build_simple_model(vocab_size, SEQ_LENGTH, EMBEDDING_DIM, RNN_UNITS)

    print("\nModel Summary:")
    model.summary()

    # Train model
    history = train_model(model, X, y, EPOCHS, BATCH_SIZE)

    # Save history for later plotting
    with open('training_history_rnn.pickle', 'wb') as handle:
        pickle.dump(history.history, handle, protocol=pickle.HIGHEST_PROTOCOL)

    # Save model and tokenizer for later use
    model.save('bangla_word_prediction_rnn_model.h5')
    with open('tokenizer_rnn.pickle', 'wb') as handle:
        pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

    print("Model training complete and saved!")

    # Interactive prediction
    print("\nWord Prediction Interface (Type 'exit' to quit)")
    while True:
        user_input = input("Enter some Bangla text: ")
        if user_input.lower() == 'exit':
            break

        if len(user_input.split()) < SEQ_LENGTH:
            print(f"Please enter at least {SEQ_LENGTH} words for better prediction.")
            continue

        predictions = predict_next_word(model, tokenizer, user_input, SEQ_LENGTH)
        print("Top predictions:", predictions)

if __name__ == "__main__":
    main()

# Load history and plot
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# Load the history
try:
    with open('training_history_rnn.pickle', 'rb') as handle:
        history_dict = pickle.load(handle)
except:
    print("Training history file not found. Using dummy data for demonstration.")
    # Create dummy history for demonstration
    history_dict = {
        'loss': [2.5, 1.8, 1.3, 1.0, 0.8, 0.6, 0.5, 0.4, 0.35, 0.3],
        'accuracy': [0.2, 0.35, 0.5, 0.6, 0.7, 0.75, 0.8, 0.82, 0.85, 0.87]
    }

# Set up the style for beautiful plots
plt.style.use('default')
sns.set_palette("husl")

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot training accuracy values
ax1.plot(history_dict['accuracy'], linewidth=3, label='Training Accuracy')
if 'val_accuracy' in history_dict:
    ax1.plot(history_dict['val_accuracy'], linewidth=3, label='Validation Accuracy')
ax1.set_title('Model Accuracy (SimpleRNN)', fontsize=16, fontweight='bold', pad=20)
ax1.set_ylabel('Accuracy', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch', fontsize=14, fontweight='bold')
ax1.legend(loc='lower right', fontsize=12)
ax1.grid(True, alpha=0.3)
ax1.tick_params(axis='both', which='major', labelsize=12)

# Plot training loss values
ax2.plot(history_dict['loss'], linewidth=3, label='Training Loss')
if 'val_loss' in history_dict:
    ax2.plot(history_dict['val_loss'], linewidth=3, label='Validation Loss')
ax2.set_title('Model Loss (SimpleRNN)', fontsize=16, fontweight='bold', pad=20)
ax2.set_ylabel('Loss', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch', fontsize=14, fontweight='bold')
ax2.legend(loc='upper right', fontsize=12)
ax2.grid(True, alpha=0.3)
ax2.tick_params(axis='both', which='major', labelsize=12)

# Add a title for the entire figure
plt.suptitle('Bangla Word Prediction Model Training Performance (SimpleRNN)', fontsize=18, fontweight='bold', y=0.98)

# Adjust layout and display
plt.tight_layout()
plt.show()
# Out:
# Loading and preprocessing data...
# Successfully read Excel file
# Columns: ['segment_id', 'text', 'segment_type', 'metadata']
# Using column 'text' for Bangla text
# Loaded 2478 words from dataset
# Sample words: ['এরকম', 'ঘটনা', 'এই', 'শহরে', 'এর', 'আগে', 'ঘটেনি', 'তার', 'আগে', 'শহরটার']
# Created 2473 sequences
# Vocabulary size: 1168
# Input shape: (2473, 5), Output shape: (2473, 1168)
#
# Building complex RNN model...
#
# ==================================================
# BUILDING MODEL ARCHITECTURE (SimpleRNN)
# ==================================================
# Adding Embedding layer: input_dim=1168, output_dim=128, input_length=5
# Adding Bidirectional SimpleRNN layer: units=256, return_sequences=True
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Adding Dropout layer: rate=0.3
# Adding SimpleRNN layer: units=256
# Adding Dropout layer: rate=0.3
# Adding Dense layer: units=256, activation='relu'
# Adding Dropout layer: rate=0.2
# Adding Output Dense layer: units=1168, activation='softmax'
#
# ==================================================
# COMPILING MODEL
# ==================================================
# Using categorical_crossentropy loss function
# Using adam optimizer
# Tracking accuracy metric
#
# Model Summary:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# ==================================================
# TRAINING MODEL
# ==================================================
# Training on 2473 samples
# Using batch size: 64
# Maximum epochs: 100
# Using callbacks: EarlyStopping, ReduceLROnPlateau
#
# Starting training...
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.0114 - loss: 7.0338 - learning_rate: 0.0010
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0290 - loss: 6.5085 - learning_rate: 0.0010
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0322 - loss: 5.9905 - learning_rate: 0.0010
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0701 - loss: 5.4110 - learning_rate: 0.0010
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1744 - loss: 4.6221 - learning_rate: 0.0010
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3185 - loss: 3.7355 - learning_rate: 0.0010
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4830 - loss: 2.7256 - learning_rate: 0.0010
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6665 - loss: 1.7560 - learning_rate: 0.0010
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8464 - loss: 0.9222 - learning_rate: 0.0010
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9451 - loss: 0.4583 - learning_rate: 0.0010
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9670 - loss: 0.2689 - learning_rate: 0.0010
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9884 - loss: 0.1556 - learning_rate: 0.0010
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9888 - loss: 0.1090 - learning_rate: 0.0010
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9965 - loss: 0.0794 - learning_rate: 0.0010
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9956 - loss: 0.0626 - learning_rate: 0.0010
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9962 - loss: 0.0538 - learning_rate: 0.0010
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0562 - learning_rate: 0.0010
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9954 - loss: 0.0425 - learning_rate: 0.0010
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9976 - loss: 0.0356 - learning_rate: 0.0010
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9982 - loss: 0.0303 - learning_rate: 0.0010
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9942 - loss: 0.0411 - learning_rate: 0.0010
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9949 - loss: 0.0338 - learning_rate: 0.0010
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9949 - loss: 0.0383 - learning_rate: 0.0010
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9925 - loss: 0.0512 - learning_rate: 0.0010
# Epoch 25/100
# 31/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9935 - loss: 0.0611
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9932 - loss: 0.0616 - learning_rate: 0.0010
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - loss: 0.0437 - learning_rate: 5.0000e-04
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0235 - learning_rate: 5.0000e-04
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0186 - learning_rate: 5.0000e-04
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9980 - loss: 0.0179 - learning_rate: 5.0000e-04
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0147 - learning_rate: 5.0000e-04
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9980 - loss: 0.0171 - learning_rate: 5.0000e-04
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0119 - learning_rate: 5.0000e-04
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0107 - learning_rate: 5.0000e-04
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0106 - learning_rate: 5.0000e-04
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0079 - learning_rate: 5.0000e-04
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0096 - learning_rate: 5.0000e-04
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0065 - learning_rate: 5.0000e-04
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9977 - loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0079 - learning_rate: 5.0000e-04
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 43/100
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0079
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0078 - learning_rate: 5.0000e-04
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9982 - loss: 0.0081 - learning_rate: 2.5000e-04
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9994 - loss: 0.0069 - learning_rate: 2.5000e-04
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9987 - loss: 0.0078 - learning_rate: 2.5000e-04
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0050 - learning_rate: 2.5000e-04
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0060 - learning_rate: 2.5000e-04
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0041 - learning_rate: 2.5000e-04
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9998 - loss: 0.0062 - learning_rate: 2.5000e-04
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9989 - loss: 0.0068 - learning_rate: 2.5000e-04
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0087 - learning_rate: 2.5000e-04
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9983 - loss: 0.0054 - learning_rate: 2.5000e-04
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9994 - loss: 0.0061
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9994 - loss: 0.0061 - learning_rate: 2.5000e-04
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9997 - loss: 0.0043 - learning_rate: 1.2500e-04
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0043 - learning_rate: 1.2500e-04
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0048 - learning_rate: 1.2500e-04
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0050 - learning_rate: 1.2500e-04
# Epoch 60/100
# 31/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0043
# Epoch 60: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0044 - learning_rate: 1.2500e-04
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0044 - learning_rate: 6.2500e-05
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0038 - learning_rate: 6.2500e-05
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0045 - learning_rate: 6.2500e-05
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9999 - loss: 0.0046 - learning_rate: 6.2500e-05
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0035 - learning_rate: 6.2500e-05
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0038 - learning_rate: 6.2500e-05
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9996 - loss: 0.0036 - learning_rate: 6.2500e-05
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9998 - loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0037 - learning_rate: 6.2500e-05
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9998 - loss: 0.0037 - learning_rate: 6.2500e-05
# Epoch 71/100
# 32/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9989 - loss: 0.0043
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0041 - learning_rate: 6.2500e-05
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0035 - learning_rate: 3.1250e-05
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0034 - learning_rate: 3.1250e-05
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9989 - loss: 0.0043 - learning_rate: 3.1250e-05
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0042 - learning_rate: 3.1250e-05
# Epoch 76/100
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0040 - learning_rate: 3.1250e-05
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0037 - learning_rate: 1.5625e-05
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0041 - learning_rate: 1.5625e-05
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0044 - learning_rate: 1.5625e-05
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0030 - learning_rate: 1.5625e-05
# Epoch 81/100
# 33/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0036
# Epoch 81: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9995 - loss: 0.0036 - learning_rate: 1.5625e-05
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9999 - loss: 0.0028 - learning_rate: 7.8125e-06
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9991 - loss: 0.0039 - learning_rate: 7.8125e-06
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0054 - learning_rate: 7.8125e-06
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9997 - loss: 0.0027 - learning_rate: 7.8125e-06
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9990 - loss: 0.0038 - learning_rate: 7.8125e-06
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9994 - loss: 0.0051 - learning_rate: 7.8125e-06
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9983 - loss: 0.0083 - learning_rate: 7.8125e-06
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9988 - loss: 0.0045 - learning_rate: 7.8125e-06
# Epoch 90/100
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0040
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9993 - loss: 0.0040 - learning_rate: 7.8125e-06
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9992 - loss: 0.0035 - learning_rate: 3.9063e-06
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0043 - learning_rate: 3.9063e-06
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9998 - loss: 0.0030 - learning_rate: 3.9063e-06
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9981 - loss: 0.0048 - learning_rate: 3.9063e-06
# Epoch 95/100
# 34/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9999 - loss: 0.0040
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9998 - loss: 0.0040 - learning_rate: 3.9063e-06
# Epoch 95: early stopping
# Restoring model weights from the end of the best epoch: 85.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training completed in 39.52 seconds
# Model training complete and saved!
#
# Word Prediction Interface (Type 'exit' to quit)
# Enter some Bangla text: এই শহের এর আেগ
# Please enter at least 5 words for better prediction.
# Enter some Bangla text: হিমালয়ের এই তল্লাটের আরও কিছু নামী-দামি শহর আছে
# Top predictions: ['যেখানে', 'লাগে', 'বাইরের']
# Enter some Bangla text: এবার অফিসার নড়ে-চড়ে বসলেন। তারপর কাগজ-কলম নিয়ে
# Top predictions: ['যুবকটিকে', 'তখন', 'ভোরে']
# Enter some Bangla text: এই শহরে যা কখনও হয়নি আজ তাই হয়েছে। সেন চেয়ারে
# Top predictions: ['শরীর', 'রেখে', 'বললেন']
# Enter some Bangla text: সেন চলে গেলে মনে হল আজকের সকালটা খুব বিশ্রী। এত
# Top predictions: ['জায়গা', 'অনুরোধ', 'সুন্দর']
# Enter some Bangla text: মেয়েটি সামান্য মাথা দুলিয়ে হাসল। তারপর
# Top predictions: ['জিজ্ঞাসা', 'চেনাশোনা', 'গেল']
# Enter some Bangla text: exit
